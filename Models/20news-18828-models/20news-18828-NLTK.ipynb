# %%
import os
import string
import numpy as np
import pandas as pd
import re
import nltk
import spacy
from spacy import displacy
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

nlp = spacy.load('en_core_web_lg')

# %% [markdown]
# ### Read Data

# %%
root_folder = r'DCourses4th year2nd termNLPProjectsNews Group20news-18828'
sub_folders = os.listdir(root_folder)
len(sub_folders)
# Out:
# 20

# %%
sub_folders
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
def read_data(root_folder, sub_folders):

    data, labels = [], []
    
    for folder in sub_folders:
        path = os.path.join(root_folder, folder)
        samples = os.listdir(path)

        for sample in samples:
            sample_path = os.path.join(path, sample)
            text = open(sample_path, encoding='iso-8859-1')   # 'latin-1')
            data.append(text.read())
            labels.append(folder)
    
    return data, labels

# %%
data, labels = read_data(root_folder, sub_folders)

print(len(data))
print(len(labels))
# Out:
# 19997
# 19997

# %%
print(labels[1200])
print('-' * 50 , end='\n\n')
print(data[1200])
# Out:
# comp.graphics
# --------------------------------------------------
#
# Newsgroups: comp.graphics
# Path: cantaloupe.srv.cs.cmu.edu!crabapple.srv.cs.cmu.edu!bb3.andrew.cmu.edu!news.sei.cmu.edu!cis.ohio-state.edu!pacific.mps.ohio-state.edu!linac!uwm.edu!cs.utexas.edu!sdd.hp.com!elroy.jpl.nasa.gov!ames!haven.umd.edu!darwin.sura.net!martha.utcc.utk.edu!utkvx.utk.edu!haston
# From: haston@utkvx.utk.edu (Haston, Donald Wayne)
# Subject: Church related graphics
# Message-ID: <16APR199317585997@utkvx.utk.edu>
# News-Software: VAX/VMS VNEWS 1.41
# Keywords: Christian graphics
# Sender: usenet@martha.utcc.utk.edu (USENET News System)
# Organization: University of Tennessee Computing Center
# Date: Fri, 16 Apr 1993 22:58:00 GMT
# Lines: 13
#
# I am looking for some good quality graphics files which are
# suitable for use in church-related presentations. I prefer vector,
# but anything would be helpful.
#
# If you know of bulletin boards which have collections of this nature, or
# commercial products, please inform me by email:
#
# HASTON@UTKVX.UTK.EDU
#
# Wayne Haston

# %% [markdown]
# ### Some Visualization Methods

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

print(labels[1200])

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=800, background_color='white').generate(data[1200])

# Display the word cloud
plt.figure(figsize=(8,8))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# Out:
# comp.graphics

# %%
print(labels[1200])
print('-' * 50 , end='\n\n')
displacy.render(nlp(data[1200]), style = "ent",jupyter = True)
# Out:
# comp.graphics
# --------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Newsgroups: comp.graphics</br>Path: cantaloupe.srv.cs.cmu.edu!crabapple.srv.cs.cmu.edu!bb3.andrew.cmu.edu!news.sei.cmu.edu!cis.ohio-state.edu!pacific.mps.ohio-state.edu!linac!uwm.edu!cs.utexas.edu!sdd.hp.com!elroy.jpl.nasa.gov!ames!haven.umd.edu!darwin.sura.net!martha.utcc.utk.edu!utkvx.utk.edu!haston</br>From: haston@utkvx.utk.edu (
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Haston
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Donald Wayne
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# )</br>Subject: Church related graphics</br>Message-ID: &lt;
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     16APR199317585997@utkvx.utk.edu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# &gt;</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     News-Software
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# :
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VAX/VMS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  VNEWS
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1.41
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#     </br>Keywords:
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Christian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  graphics</br>Sender: usenet@martha.utcc.utk.edu (USENET News System)</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Organization: University of Tennessee Computing Center
# Date
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# :
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fri, 16 Apr 1993
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     22:58:00
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GMT
# Lines
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# :
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br></br>I am looking for some good quality graphics files which are</br>suitable for use in church-related presentations. I prefer vector,</br>but anything would be helpful.</br></br>If you know of bulletin boards which have collections of this nature, or</br>commercial products, please inform me by email:</br></br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HASTON@UTKVX.UTK.EDU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br></br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wayne Haston
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br></br></br></br></div></span>

# %%
# displacy.render(nlp(data[1200]), style = "dep",jupyter = True, options={'distance': 80,})
# displacy.render(nlp(data[1200]), style="dep", options={"compact": True, "bg": "#09a3d5",
#                                            'distance': 80,"color": "white",
#                                            "font": "Source Sans Pro"})

# %% [markdown]
# ### Clean Header

# %%
def clean_header(text):
    text = re.sub(r'(From:\s+[^\n]+\n)', '', text)
    text = re.sub(r'(Subject:[^\n]+\n)', '', text)
    text = re.sub(r'(([\sA-Za-z0-9\-]+)?[A|a]rchive-name:[^\n]+\n)', '', text)
    text = re.sub(r'(Last-modified:[^\n]+\n)', '', text)
    text = re.sub(r'(Version:[^\n]+\n)', '', text)

    return text

# %% [markdown]
# ### Clean Text

# %%
re_url = re.compile(r'(?:http|ftp|https)://(?:[\w_-]+(?:(?:\.[\w_-]+)+))(?:[\w.,@?^=%&:/~+#-]*[\w@?^=%&/~+#-])?')
re_email = re.compile('(?:[a-z0-9!#$%&\'*+/=?^_`{|}~-]+(?:\.[a-z0-9!#$%&\'*+/=?^_`{|}~-]+)*|"(?:[\x01-\x08\x0b\x0c\x0e-\x1f\x21\x23-\x5b\x5d-\x7f]|\\[\x01-\x09\x0b\x0c\x0e-\x7f])*")@(?:(?:[a-z0-9](?:[a-z0-9-]*[a-z0-9])?\.)+[a-z0-9](?:[a-z0-9-]*[a-z0-9])?|\[(?:(?:(2(5[0-5]|[0-4][0-9])|1[0-9][0-9]|[1-9]?[0-9]))\.){3}(?:(2(5[0-5]|[0-4][0-9])|1[0-9][0-9]|[1-9]?[0-9])|[a-z0-9-]*[a-z0-9]:(?:[\x01-\x08\x0b\x0c\x0e-\x1f\x21-\x5a\x53-\x7f]|\\[\x01-\x09\x0b\x0c\x0e-\x7f])+)\])')                 

def clean_text(text):        
    text = text.lower()
    text = text.strip()
    text = re.sub(re_url, '', text)
    text = re.sub(re_email, '', text)
    text = re.sub(f'[{re.escape(string.punctuation)}]', '', text)
    text = re.sub(r'(\d+)', ' ', text)
    text = re.sub(r'(\s+)', ' ', text)
    
    return text

# %%
for i in range(len(data)):
    data[i] = clean_text(clean_header(data[i]))

# %% [markdown]
# ### Tokenization

# %%
tokenized_data = []
for i in range(len(data)):
    tokenized_data.append(nltk.word_tokenize(data[i]))

# %% [markdown]
# ### Remove Stopwords

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
print(len(stop_words))
stop_words
# Out:
# 179
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
filtered_data = []

for i in range(len(tokenized_data)):
    filtered_doc = [w for w in tokenized_data[i] if not w in stop_words]
    filtered_data.append(filtered_doc)

# %% [markdown]
# ### Stemming & Lemmatization

# %%
from nltk.stem import WordNetLemmatizer, PorterStemmer
lemmatizer = WordNetLemmatizer()
# stemmer = PorterStemmer()

final_data = []

for i in range(len(filtered_data)):
    lemmatized_text = ' '.join(lemmatizer.lemmatize(token) for token in filtered_data[i])
    final_data.append(lemmatized_text)

# for i in range(len(filtered_data)):
#     stemmed_text = ' '.join(stemmer.stem(token) for token in filtered_data[i])
#     final_data.append(stemmed_text)

# %%
max_ = 0
for doc in final_data:
    max_ = max(max_, len(doc))
print(f'max length: {max_}')
# Out:
# max length: 79103

# %%
max_ = 0
for doc in final_data:
    max_ = max(max_, len(set(doc)))
print(f'max distinct words: {max_}')
# Out:
# max distinct words: 56

# %% [markdown]
# ### Note
#
# You should split before tf-idf.
#
# If you learn tf-idf also on the test set you will have data leakage. In example, you won't have out-of-vocabulary words in inference on the test set, what might happen in the "real world".

# %% [markdown]
# ### Data Splitting

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
encoded_labels = le.fit_transform(labels)

# %%
encoded_labels
# Out:
# array([ 0,  0,  0, ..., 19, 19, 19], dtype=int64)

# %%
X_train, X_test, y_train, y_test = train_test_split(final_data, encoded_labels, test_size=0.2, stratify=labels, shuffle=True, random_state=42)

# %%
print(len(X_train))
print(len(X_test))
print(y_train.shape)
print(y_test.shape)
# Out:
# 15997
# 4000
# (15997,)
# (4000,)

# %% [markdown]
# ### TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(analyzer='word', min_df=5, max_df=0.4)
tf_idf = vectorizer.fit(X_train)

# %%
tf_idf
# Out:
# TfidfVectorizer(max_df=0.4, min_df=5)

# %%
X_train = tf_idf.transform(X_train).toarray()
X_test = tf_idf.transform(X_test).toarray()

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (15997, 24294)
# (4000, 24294)
# (15997,)
# (4000,)

# %% [markdown]
# ### RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf.predict(X_test)
print(y_pred[:24])
print(y_test[:24])
# Out:
# [11  1 17 16  5  9  6 14 10 15  2  5  4  8  3 14  3  3 10  4 14 10 19 15]
# [11  1 17 16  5  9  6 14 10 15  2  5  4  8  3 14  2  3 10  4 14 10 16 15]

# %%
cm = confusion_matrix(y_test,y_pred)
disp=ConfusionMatrixDisplay(cm)
disp.plot()

# %%
print(f"Train Accuracy: {rf.score(X_train, y_train)*100:.3f}%")
print(f"Test Accuracy: {rf.score(X_test, y_test)*100:.3f}%")
# Out:
# Train Accuracy: 97.881%
# Test Accuracy: 94.450%

# %% [markdown]
# ### MLP

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=(20), activation='relu', random_state=42)

mlp.fit(X_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=20, random_state=42)

# %%
y_pred = mlp.predict(X_test)

print(y_pred[:24])
print(y_test[:24])
# Out:
# [11  1 17 16  5  9  6 14 10 15  2  5  4  8  3 14  3  3 10  4 14 10 19 15]
# [11  1 17 16  5  9  6 14 10 15  2  5  4  8  3 14  2  3 10  4 14 10 16 15]

# %%
cm = confusion_matrix(y_test,y_pred)
disp=ConfusionMatrixDisplay(cm)
disp.plot()

# %%
print(f"Train Accuracy: {mlp.score(X_train, y_train)*100:.3f}%")
print(f"Test Accuracy: {mlp.score(X_test, y_test)*100:.3f}%")
# Out:
# Train Accuracy: 97.881%
# Test Accuracy: 93.100%

# %% [markdown]
# ### Adaboost

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

adaboost = AdaBoostClassifier(DecisionTreeClassifier(max_depth=5),
                         algorithm="SAMME",
                        # n_estimators=100,
                         random_state=42)

adaboost.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15868\449874991.py in <module>
#       7                          random_state=42)
#       8
# ----> 9 adaboost.fit(X_train,y_train)
#
# c:\Users\mohamed\anaconda3-folder\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py in fit(self, X, y, sample_weight)
#     484
#     485         # Fit
# --> 486         return super().fit(X, y, sample_weight)
#     487
#     488     def _validate_estimator(self):
#
# c:\Users\mohamed\anaconda3-folder\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py in fit(self, X, y, sample_weight)
#     143         for iboost in range(self.n_estimators):
#     144             # Boosting step
# --> 145             sample_weight, estimator_weight, estimator_error = self._boost(
#     146                 iboost, X, y, sample_weight, random_state
#     147             )
#
# c:\Users\mohamed\anaconda3-folder\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py in _boost(self, iboost, X, y, sample_weight, random_state)
#     549
#     550         else:  # elif self.algorithm == "SAMME":
# --> 551             return self._boost_discrete(iboost, X, y, sample_weight, random_state)
#     552
#     553     def _boost_real(self, iboost, X, y, sample_weight, random_state):
#
# c:\Users\mohamed\anaconda3-folder\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py in _boost_discrete(self, iboost, X, y, sample_weight, random_state)
#     614         estimator = self._make_estimator(random_state=random_state)
#     615
# --> 616         estimator.fit(X, y, sample_weight=sample_weight)
#     617
#     618         y_predict = estimator.predict(X)
#
# c:\Users\mohamed\anaconda3-folder\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     935         """
#     936
# --> 937         super().fit(
#     938             X,
#     939             y,
#
# c:\Users\mohamed\anaconda3-folder\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     163             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     164             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 165             X, y = self._validate_data(
#     166                 X, y, validate_separately=(check_X_params, check_y_params)
#     167             )
#
# c:\Users\mohamed\anaconda3-folder\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     576                 # :(
#     577                 check_X_params, check_y_params = validate_separately
# --> 578                 X = check_array(X, **check_X_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
#
# c:\Users\mohamed\anaconda3-folder\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744                     array = array.astype(dtype, casting="unsafe", copy=False)
#     745                 else:
# --> 746                     array = np.asarray(array, order=order, dtype=dtype)
#     747             except ComplexWarning as complex_warning:
#     748                 raise ValueError(
#
# KeyboardInterrupt:

# %%
y_pred = adaboost.predict(X_test)

print(y_pred[:24])
print(y_test[:24])
# Out:
# [14  4  7  0 18  9  2  8  1 18 15 10  9 10 18  8 15  2 11 12  4 12  0 12]
# [14  4  7  0 19  9  2  8  1 18 15 10  9 10 18  8 15  2 11 12  4 12  0 12]

# %%
cm = confusion_matrix(y_test,y_pred)
disp=ConfusionMatrixDisplay(cm)
disp.plot()

# %%
print(f"Train Accuracy: {adaboost.score(X_train, y_train)*100:.3f}%")
print(f"Test Accuracy: {adaboost.score(X_test, y_test)*100:.3f}%")
# Out:
# Train Accuracy: 97.887%
# Test Accuracy: 94.250%

# %% [markdown]
# ### Decision Tree

# %%
decisiontree = DecisionTreeClassifier(max_depth=5, random_state=42)
decisiontree.fit(X_train,y_train)

# %%
y_pred = decisiontree.predict(X_test)

print(y_pred[:24])
print(y_test[:24])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13668\1898885849.py in <module>
# ----> 1 y_pred = adaboost.predict(X_val)
#       2
#       3 print(y_pred[:24])
#       4 print(y_val[:24])
#
# c:\Users\mohamed\anaconda3-folder\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py in predict(self, X)
#     677             The predicted classes.
#     678         """
# --> 679         pred = self.decision_function(X)
#     680
#     681         if self.n_classes_ == 2:
#
# c:\Users\mohamed\anaconda3-folder\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py in decision_function(self, X)
#     749             )
#     750         else:  # self.algorithm == "SAMME"
# --> 751             pred = sum(
#     752                 (estimator.predict(X) == classes).T * w
#     753                 for estimator, w in zip(self.estimators_, self.estimator_weights_)
#
# c:\Users\mohamed\anaconda3-folder\anaconda3\lib\site-packages\sklearn\ensemble\_weight_boosting.py in <genexpr>(.0)
#     750         else:  # self.algorithm == "SAMME"
#     751             pred = sum(
# --> 752                 (estimator.predict(X) == classes).T * w
#     753                 for estimator, w in zip(self.estimators_, self.estimator_weights_)
#     754             )
#
# c:\Users\mohamed\anaconda3-folder\anaconda3\lib\site-packages\sklearn\tree\_classes.py in predict(self, X, check_input)
#     472         if is_classifier(self):
#     473             if self.n_outputs_ == 1:
# --> 474                 return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#     475
#     476             else:
#
# AttributeError: 'list' object has no attribute 'take'

# %%
cm = confusion_matrix(y_test,y_pred)
disp=ConfusionMatrixDisplay(cm)
disp.plot()

# %%
print(f"Train Accuracy: {decisiontree.score(X_train, y_train)*100:.3f}%")
print(f"Test Accuracy: {decisiontree.score(X_test, y_test)*100:.3f}%")
# Out:
# Train Accuracy: 97.887%
# Test Accuracy: 94.250%

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=100)

# Train the classifier
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=100)

# %%
y_pred = knn.predict(X_test)

print(y_pred[:24])
print(y_test[:24])
# Out:
# [11  1 17 16  5  9  6 14 10  0  2  5  4  8  3  1  3 10 10  3 14 10 16 15]
# [11  1 17 16  5  9  6 14 10 15  2  5  4  8  3 14  2  3 10  4 14 10 16 15]
# c:\Users\mohamed\anaconda3-folder\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
cm = confusion_matrix(y_test,y_pred)
disp=ConfusionMatrixDisplay(cm)
disp.plot()

# %%
print(f"Train Accuracy: {knn.score(X_train, y_train)*100:.3f}%")
print(f"Test Accuracy: {knn.score(X_test, y_test)*100:.3f}%")
# Out:
# c:\Users\mohamed\anaconda3-folder\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# Train Accuracy: 83.534%
# Test Accuracy: 83.400%
# c:\Users\mohamed\anaconda3-folder\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(X_test)

print(y_pred[:24])
print(y_test[:24])
# Out:
# [11  1 17 16  1  9  6 14 10 15  2  5  4  8  3 14  3  3 10  1 14 10 19 15]
# [11  1 17 16  5  9  6 14 10 15  2  5  4  8  3 14  2  3 10  4 14 10 16 15]

# %%
cm = confusion_matrix(y_test,y_pred)
disp=ConfusionMatrixDisplay(cm)
disp.plot()

# %%
print(f"Train Accuracy: {gnb.score(X_train, y_train)*100:.3f}%")
print(f"Test Accuracy: {gnb.score(X_test, y_test)*100:.3f}%")
# Out:
# Train Accuracy: 97.006%
# Test Accuracy: 78.450%
